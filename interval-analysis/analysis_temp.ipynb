# %%
# Import data from JSON file

import json
import pandas as pd

data = []
with open('temp.json') as f:
  data = json.load(f)

# Turn list into dataframe
df = pd.DataFrame(data)

# Print the first few rows of the dataframe
print(df.head())
# Out:
#         temp  _creationTime                          deviceId
# 0  27.037340  1716380669793  j571a1ejhbg100tj6v229rz95s6qyzj3
# 1  26.817568  1716380670807  j571a1ejhbg100tj6v229rz95s6qyzj3
# 2  26.964083  1716380671824  j571a1ejhbg100tj6v229rz95s6qyzj3
# 3  27.073969  1716380672838  j571a1ejhbg100tj6v229rz95s6qyzj3
# 4  27.019026  1716380673856  j571a1ejhbg100tj6v229rz95s6qyzj3

# %%
# Plot the data
data_1s = df['temp'][:240]

# If data would be collected every 5 seconds
data_5s = data_1s[::5]

# If data would be collected every 10 seconds
data_10s = data_1s[::10]

# If data would be collected every 20 seconds
data_20s = data_1s[::20]

# %%
mean_1s = data_1s.mean()
mean_5s = data_5s.mean()
mean_10s = data_10s.mean()
mean_20s = data_20s.mean()

print('Mean temperature for 1s data: ', mean_1s)
print('Mean temperature for 5s data: ', mean_5s)
print('Mean temperature for 10s data: ', mean_10s)
print('Mean temperature for 20s data: ', mean_20s)
# Out:
# Mean temperature for 1s data:  27.029022391637167
# Mean temperature for 5s data:  27.01635495821635
# Mean temperature for 10s data:  27.01826270421346
# Mean temperature for 20s data:  27.031235376993816

# %%
std_1s = data_1s.std()
std_5s = data_5s.std()
std_10s = data_10s.std()
std_20s = data_20s.std()

print('Standard deviation for 1s data: ', std_1s)
print('Standard deviation for 5s data: ', std_5s)
print('Standard deviation for 10s data: ', std_10s)
print('Standard deviation for 20s data: ', std_20s)
# Out:
# Standard deviation for 1s data:  0.06586840790338586
# Standard deviation for 5s data:  0.05193699120687533
# Standard deviation for 10s data:  0.04469120835270113
# Standard deviation for 20s data:  0.03606947315623636

# %%
max_1s = data_1s.max()
max_5s = data_5s.max()
max_10s = data_10s.max()
max_20s = data_20s.max()

min_1s = data_1s.min()
min_5s = data_5s.min()
min_10s = data_10s.min()
min_20s = data_20s.min()

print('Max temperature for 1s data: ', max_1s)
print('Max temperature for 5s data: ', max_5s)
print('Max temperature for 10s data: ', max_10s)
print('Max temperature for 20s data: ', max_20s)
print('\n')
print('Min temperature for 1s data: ', min_1s)
print('Min temperature for 5s data: ', min_5s)
print('Min temperature for 10s data: ', min_10s)
print('Min temperature for 20s data: ', min_20s)
# Out:
# Max temperature for 1s data:  27.220483779907227
# Max temperature for 5s data:  27.1289119720459
# Max temperature for 10s data:  27.1289119720459
# Max temperature for 20s data:  27.092283248901367
#
#
# Min temperature for 1s data:  26.74431037902832
# Min temperature for 5s data:  26.83588218688965
# Min temperature for 10s data:  26.927453994750977
# Min temperature for 20s data:  26.982397079467773

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.plot(data_1s, label='1s interval')
plt.plot(data_5s, label='5s interval')
plt.plot(data_10s, label='10s interval')
plt.plot(data_20s, label='20s interval')
plt.axhline(mean_1s, color='r', linestyle='--', label='Mean 1s')
plt.legend()
plt.show()

# %%
# Perform t-test on data_1s and data_10s
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(data_1s, data_5s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)

t_stat, p_value = ttest_ind(data_1s, data_10s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)

t_stat, p_value = ttest_ind(data_1s, data_20s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)
# Out:
# T-statistic:  1.255966273214399
# P-value:  0.2101532297377903
# T-statistic:  0.7817546663497337
# P-value:  0.43506465006165307
# T-statistic:  -0.11536975729723291
# P-value:  0.9082446603367975
