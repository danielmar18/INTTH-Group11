# %%
# Import data from JSON file

import json
import pandas as pd

data = []
with open('humid.json') as f:
  data = json.load(f)

# Turn list into dataframe
df = pd.DataFrame(data)

# Print the first few rows of the dataframe
print(df.head())
# Out:
#     humidity  _creationTime                          deviceId
# 0  54.148964  1716380669824  j571a1ejhbg100tj6v229rz95s6qyzj3
# 1  53.939316  1716380670845  j571a1ejhbg100tj6v229rz95s6qyzj3
# 2  54.019478  1716380671857  j571a1ejhbg100tj6v229rz95s6qyzj3
# 3  53.273376  1716380672872  j571a1ejhbg100tj6v229rz95s6qyzj3
# 4  54.959805  1716380673901  j571a1ejhbg100tj6v229rz95s6qyzj3

# %%
# Plot the data
data_1s = df['humidity'][:240]

# If data would be collected every 5 seconds
data_5s = data_1s[::5]

# If data would be collected every 10 seconds
data_10s = data_1s[::10]

# If data would be collected every 20 seconds
data_20s = data_1s[::20]

# %%
mean_1s = data_1s.mean()
mean_5s = data_5s.mean()
mean_10s = data_10s.mean()
mean_20s = data_20s.mean()

print('Mean temperature for 1s data: ', mean_1s)
print('Mean temperature for 5s data: ', mean_5s)
print('Mean temperature for 10s data: ', mean_10s)
print('Mean temperature for 20s data: ', mean_20s)
# Out:
# Mean temperature for 1s data:  54.05579144159953
# Mean temperature for 5s data:  54.02474292119344
# Mean temperature for 10s data:  54.05493132273356
# Mean temperature for 20s data:  54.067520459493004

# %%
std_1s = data_1s.std()
std_5s = data_5s.std()
std_10s = data_10s.std()
std_20s = data_20s.std()

print('Standard deviation for 1s data: ', std_1s)
print('Standard deviation for 5s data: ', std_5s)
print('Standard deviation for 10s data: ', std_10s)
print('Standard deviation for 20s data: ', std_20s)
# Out:
# Standard deviation for 1s data:  0.4548010724052152
# Standard deviation for 5s data:  0.4599880048153304
# Standard deviation for 10s data:  0.4907537079606865
# Standard deviation for 20s data:  0.4338772171881763

# %%
max_1s = data_1s.max()
max_5s = data_5s.max()
max_10s = data_10s.max()
max_20s = data_20s.max()

min_1s = data_1s.min()
min_5s = data_5s.min()
min_10s = data_10s.min()
min_20s = data_20s.min()

print('Max temperature for 1s data: ', max_1s)
print('Max temperature for 5s data: ', max_5s)
print('Max temperature for 10s data: ', max_10s)
print('Max temperature for 20s data: ', max_20s)
print('\n')
print('Min temperature for 1s data: ', min_1s)
print('Min temperature for 5s data: ', min_5s)
print('Min temperature for 10s data: ', min_10s)
print('Min temperature for 20s data: ', min_20s)
# Out:
# Max temperature for 1s data:  55.573333740234375
# Max temperature for 5s data:  54.867313385009766
# Max temperature for 10s data:  54.867313385009766
# Max temperature for 20s data:  54.867313385009766
#
#
# Min temperature for 1s data:  51.99391174316406
# Min temperature for 5s data:  52.860252380371094
# Min temperature for 10s data:  52.860252380371094
# Min temperature for 20s data:  53.227134704589844

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.plot(data_1s, label='1s interval')
plt.plot(data_5s, label='5s interval')
plt.plot(data_10s, label='10s interval')
plt.plot(data_20s, label='20s interval')
plt.axhline(mean_1s, color='r', linestyle='--', label='Mean 1s')
plt.legend()
plt.show()

# %%
# Perform t-test on data_1s and data_10s
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(data_1s, data_5s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)

t_stat, p_value = ttest_ind(data_1s, data_10s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)

t_stat, p_value = ttest_ind(data_1s, data_20s)
print('T-statistic: ', t_stat)
print('P-value: ', p_value)
# Out:
# T-statistic:  0.4309554309401511
# P-value:  0.6668253996859973
# T-statistic:  0.008770729040376736
# P-value:  0.9930087349964123
# T-statistic:  -0.08735680881799038
# P-value:  0.930457829394019
